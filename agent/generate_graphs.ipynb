# %%
# !pip3 install strands-agents-tools strands-agents anthropic
# Out:
# Collecting strands-agents-tools
#   Downloading strands_agents_tools-0.2.7-py3-none-any.whl.metadata (45 kB)
# Collecting strands-agents
#   Downloading strands_agents-1.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting anthropic
#   Downloading anthropic-0.67.0-py3-none-any.whl.metadata (27 kB)
# Collecting aiohttp<4.0.0,>=3.8.0 (from strands-agents-tools)
#   Downloading aiohttp-3.12.15-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting aws-requests-auth<0.5.0,>=0.4.3 (from strands-agents-tools)
#   Downloading aws_requests_auth-0.4.3-py2.py3-none-any.whl.metadata (567 bytes)
# Collecting botocore<2.0.0,>=1.39.7 (from strands-agents-tools)
#   Downloading botocore-1.40.30-py3-none-any.whl.metadata (5.7 kB)
# Collecting dill<0.5.0,>=0.4.0 (from strands-agents-tools)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting markdownify<2.0.0,>=1.0.0 (from strands-agents-tools)
#   Downloading markdownify-1.2.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting pillow<12.0.0,>=11.2.1 (from strands-agents-tools)
#   Downloading pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (3.0.52)
# Collecting pyjwt<3.0.0,>=2.10.1 (from strands-agents-tools)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting readabilipy<1.0.0,>=0.2.0 (from strands-agents-tools)
#   Downloading readabilipy-0.3.0-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (2.32.3)
# Collecting rich<15.0.0,>=14.0.0 (from strands-agents-tools)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting slack-bolt<2.0.0,>=1.23.0 (from strands-agents-tools)
#   Downloading slack_bolt-1.25.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting sympy<2.0.0,>=1.12.0 (from strands-agents-tools)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting tenacity<10.0.0,>=9.1.2 (from strands-agents-tools)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting watchdog<7.0.0,>=6.0.0 (from strands-agents-tools)
#   Downloading watchdog-6.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (44 kB)
# Collecting boto3<2.0.0,>=1.26.0 (from strands-agents)
#   Downloading boto3-1.40.30-py3-none-any.whl.metadata (6.7 kB)
# Collecting docstring-parser<1.0,>=0.15 (from strands-agents)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting mcp<2.0.0,>=1.11.0 (from strands-agents)
#   Downloading mcp-1.14.0-py3-none-any.whl.metadata (75 kB)
# Collecting opentelemetry-api<2.0.0,>=1.30.0 (from strands-agents)
#   Downloading opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 (from strands-agents)
#   Downloading opentelemetry_instrumentation_threading-0.58b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.30.0 (from strands-agents)
#   Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents) (2.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from anthropic) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from anthropic) (0.25.2)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from anthropic) (1.3.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools)
#   Downloading frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools)
#   Downloading multidict-6.6.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools)
#   Downloading propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools)
#   Downloading yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.8 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic) (3.7)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.26.0->strands-agents)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3<2.0.0,>=1.26.0->strands-agents)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from botocore<2.0.0,>=1.39.7->strands-agents-tools) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from botocore<2.0.0,>=1.39.7->strands-agents-tools) (2.2.3)
# Requirement already satisfied: certifi in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (4.13.5)
# Requirement already satisfied: six<2,>=1.15 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (1.17.0)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting httpx-sse>=0.4 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (4.25.1)
# Collecting pydantic-settings>=2.5.2 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic<3.0.0,>=2.4.0 (from strands-agents)
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting python-multipart>=0.0.9 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: starlette>=0.27 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.27.0)
# Collecting uvicorn>=0.31.1 (from mcp<2.0.0,>=1.11.0->strands-agents)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-instrumentation==0.58b0 (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents)
#   Downloading opentelemetry_instrumentation-0.58b0-py3-none-any.whl.metadata (7.1 kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents)
#   Downloading wrapt-1.17.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents)
#   Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging>=18.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (24.1)
# Requirement already satisfied: wcwidth in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.4.0->strands-agents)
#   Downloading pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.4.0->strands-agents)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting html5lib (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting lxml (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools)
#   Downloading lxml-6.0.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.8 kB)
# Collecting regex (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools)
#   Downloading regex-2025.9.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.3.2)
# Collecting markdown-it-py>=2.2.0 (from rich<15.0.0,>=14.0.0->strands-agents-tools)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (2.19.2)
# Collecting slack_sdk<4,>=3.35.0 (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools)
#   Downloading slack_sdk-3.36.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy<2.0.0,>=1.12.0->strands-agents-tools)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools) (2.8)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents) (0.27.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents) (1.0.0)
# Requirement already satisfied: click>=7.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents) (8.2.1)
# Requirement already satisfied: webencodings in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools) (0.5.1)
# Downloading strands_agents_tools-0.2.7-py3-none-any.whl (282 kB)
# Downloading strands_agents-1.8.0-py3-none-any.whl (203 kB)
# Downloading anthropic-0.67.0-py3-none-any.whl (317 kB)
# Downloading aiohttp-3.12.15-cp312-cp312-macosx_11_0_arm64.whl (469 kB)
# Downloading aws_requests_auth-0.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading boto3-1.40.30-py3-none-any.whl (139 kB)
# Downloading botocore-1.40.30-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 8.7 MB/s eta 0:00:00a 0:00:01
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading jiter-0.10.0-cp312-cp312-macosx_11_0_arm64.whl (320 kB)
# Downloading markdownify-1.2.0-py3-none-any.whl (15 kB)
# Downloading mcp-1.14.0-py3-none-any.whl (163 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_instrumentation_threading-0.58b0-py3-none-any.whl (9.3 kB)
# Downloading opentelemetry_instrumentation-0.58b0-py3-none-any.whl (33 kB)
# Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
# Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
# Downloading pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 9.1 MB/s eta 0:00:00a 0:00:01m
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.6 MB/s eta 0:00:00ta 0:00:01
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading readabilipy-0.3.0-py3-none-any.whl (22 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading slack_bolt-1.25.0-py2.py3-none-any.whl (229 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 10.8 MB/s eta 0:00:00 0:00:01m
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading watchdog-6.0.0-cp312-cp312-macosx_11_0_arm64.whl (89 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl (46 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading multidict-6.6.4-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Downloading propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Downloading slack_sdk-3.36.0-py2.py3-none-any.whl (293 kB)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading wrapt-1.17.3-cp312-cp312-macosx_11_0_arm64.whl (39 kB)
# Downloading yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl (89 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-6.0.1-cp312-cp312-macosx_10_13_universal2.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Downloading regex-2025.9.1-cp312-cp312-macosx_11_0_arm64.whl (287 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: mpmath, zipp, wrapt, watchdog, uvicorn, typing-inspection, tenacity, sympy, slack_sdk, regex, python-multipart, pyjwt, pydantic-core, propcache, pillow, multidict, mdurl, lxml, jmespath, jiter, httpx-sse, html5lib, frozenlist, docstring-parser, dill, anyio, aiohappyeyeballs, yarl, sse-starlette, slack-bolt, readabilipy, pydantic, markdownify, markdown-it-py, importlib-metadata, httpx, botocore, aws-requests-auth, aiosignal, s3transfer, rich, pydantic-settings, opentelemetry-api, anthropic, aiohttp, opentelemetry-semantic-conventions, mcp, boto3, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-threading, strands-agents, strands-agents-tools
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.24.0
#     Uninstalling uvicorn-0.24.0:
#       Successfully uninstalled uvicorn-0.24.0
#   Attempting uninstall: python-multipart
#     Found existing installation: python-multipart 0.0.6
#     Uninstalling python-multipart-0.0.6:
#       Successfully uninstalled python-multipart-0.0.6
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.1
#     Uninstalling pydantic_core-2.14.1:
#       Successfully uninstalled pydantic_core-2.14.1
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.0
#     Uninstalling pydantic-2.5.0:
#       Successfully uninstalled pydantic-2.5.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.25.2
#     Uninstalling httpx-0.25.2:
#       Successfully uninstalled httpx-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# supabase 2.3.4 requires httpx<0.26,>=0.24, but you have httpx 0.28.1 which is incompatible.
# storage3 0.7.7 requires httpx[http2]<0.28,>=0.24, but you have httpx 0.28.1 which is incompatible.
# supafunc 0.3.3 requires httpx<0.26,>=0.24, but you have httpx 0.28.1 which is incompatible.
# postgrest 0.13.2 requires httpx<0.26,>=0.24, but you have httpx 0.28.1 which is incompatible.
# gotrue 2.9.1 requires httpx[http2]<0.28,>=0.24, but you have httpx 0.28.1 which is incompatible.
# fastapi 0.104.1 requires anyio<4.0.0,>=3.7.1, but you have anyio 4.10.0 which is incompatible.
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 anthropic-0.67.0 anyio-4.10.0 aws-requests-auth-0.4.3 boto3-1.40.30 botocore-1.40.30 dill-0.4.0 docstring-parser-0.17.0 frozenlist-1.7.0 html5lib-1.1 httpx-0.28.1 httpx-sse-0.4.1 importlib-metadata-8.7.0 jiter-0.10.0 jmespath-1.0.1 lxml-6.0.1 markdown-it-py-4.0.0 markdownify-1.2.0 mcp-1.14.0 mdurl-0.1.2 mpmath-1.3.0 multidict-6.6.4 opentelemetry-api-1.37.0 opentelemetry-instrumentation-0.58b0 opentelemetry-instrumentation-threading-0.58b0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 pillow-11.3.0 propcache-0.3.2 pydantic-2.11.9 pydantic-core-2.33.2 pydantic-settings-2.10.1 pyjwt-2.10.1 python-multipart-0.0.20 readabilipy-0.3.0 regex-2025.9.1 rich-14.1.0 s3transfer-0.14.0 slack-bolt-1.25.0 slack_sdk-3.36.0 sse-starlette-3.0.2 strands-agents-1.8.0 strands-agents-tools-0.2.7 sympy-1.14.0 tenacity-9.1.2 typing-inspection-0.4.1 uvicorn-0.35.0 watchdog-6.0.0 wrapt-1.17.3 yarl-1.20.1 zipp-3.23.0

# %%
pip install 'strands-agents[litellm]' strands-agents-tools
# Out:
# Requirement already satisfied: strands-agents-tools in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (0.2.7)
# Requirement already satisfied: strands-agents[litellm] in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (1.40.30)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (1.40.30)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (1.14.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (1.37.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (0.58b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (2.11.9)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents[litellm]) (6.0.0)
# Collecting litellm<2.0.0,>=1.75.9 (from strands-agents[litellm])
#   Downloading litellm-1.77.1-py3-none-any.whl.metadata (41 kB)
# Collecting openai<1.102.0,>=1.68.0 (from strands-agents[litellm])
#   Downloading openai-1.101.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (3.12.15)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (0.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (14.1.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from strands-agents-tools) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.20.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents[litellm]) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents[litellm]) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents[litellm]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents[litellm]) (2.2.3)
# Requirement already satisfied: click in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (8.2.1)
# Collecting fastuuid>=0.12.0 (from litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading fastuuid-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.8 kB)
# Requirement already satisfied: httpx>=0.23.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (4.25.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (1.0.0)
# Collecting tiktoken>=0.7.0 (from litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting tokenizers (from litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading tokenizers-0.22.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (4.13.5)
# Requirement already satisfied: six<2,>=1.15 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (1.17.0)
# Requirement already satisfied: anyio>=4.5 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (4.10.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (0.4.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (0.27.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[litellm]) (0.35.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from openai<1.102.0,>=1.68.0->strands-agents[litellm]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from openai<1.102.0,>=1.68.0->strands-agents[litellm]) (0.10.0)
# Requirement already satisfied: sniffio in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from openai<1.102.0,>=1.68.0->strands-agents[litellm]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from openai<1.102.0,>=1.68.0->strands-agents[litellm]) (4.66.5)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[litellm]) (0.58b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[litellm]) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[litellm]) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[litellm]) (24.1)
# Requirement already satisfied: wcwidth in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[litellm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[litellm]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[litellm]) (0.4.1)
# Requirement already satisfied: html5lib in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools) (1.1)
# Requirement already satisfied: lxml in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools) (6.0.1)
# Requirement already satisfied: regex in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools) (2025.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools) (3.36.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools) (2.8)
# Requirement already satisfied: httpcore==1.* in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from httpx>=0.23.0->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools) (0.1.2)
# Requirement already satisfied: webencodings in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools) (0.5.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers->litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyyaml>=5.1 in /Users/shannonaurl/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.9->strands-agents[litellm]) (6.0.2)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.9->strands-agents[litellm])
#   Downloading hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Downloading litellm-1.77.1-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 8.8 MB/s eta 0:00:00a 0:00:01
# Downloading openai-1.101.0-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.8/810.8 kB 4.0 MB/s eta 0:00:00
# Downloading fastuuid-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (247 kB)
# Downloading tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.7/996.7 kB 9.0 MB/s eta 0:00:00
# Downloading tokenizers-0.22.0-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 8.2 MB/s eta 0:00:00ta 0:00:01
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 7.9 MB/s eta 0:00:00
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 7.2 MB/s eta 0:00:00ta 0:00:01
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Installing collected packages: hf-xet, fsspec, filelock, fastuuid, tiktoken, huggingface-hub, tokenizers, openai, litellm
# Successfully installed fastuuid-0.12.0 filelock-3.19.1 fsspec-2025.9.0 hf-xet-1.1.10 huggingface-hub-0.34.4 litellm-1.77.1 openai-1.101.0 tiktoken-0.11.0 tokenizers-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import requests
import time
import asyncio
from datetime import datetime
from strands import Agent, tool
from strands_tools import calculator
from strands.models.anthropic import AnthropicModel
from strands.models.litellm import LiteLLMModel
import anthropic

import httpx
from datetime import datetime
from typing import Dict, Any

# Configuration - set your API base URL here
BASE_URL = "http://localhost:8000"  # Change this to your deployed URL as needed

@tool
async def get_recent_financial_data(limit: int = 1000) -> dict:
    """
    Get the most recent financial data rows for analysis.
    
    Args:
        limit (int): Number of recent rows to fetch (default: 100)
    
    Returns:
        dict: Financial data response
    """
    try:
        async with httpx.AsyncClient() as client:
            response = await client.get(
                f"{BASE_URL}/api/agent-query",
                params={"limit": limit}
            )
            
            # Check if request was successful
            response.raise_for_status()
            
            # Get the raw data from the agent-query endpoint
            financial_data = response.json()
            
            # Return in the expected format
            return {
                "status": "success",
                "timestamp": datetime.now().isoformat(),
                "data": financial_data,
                "count": len(financial_data),
                "message": f"Retrieved {len(financial_data)} recent financial records for analysis"
            }
    
    except httpx.HTTPError as e:
        # Handle HTTP errors
        return {
            "status": "error",
            "timestamp": datetime.now().isoformat(),
            "data": [],
            "count": 0,
            "message": f"HTTP error occurred: {str(e)}"
        }
    
    except Exception as e:
        # Handle other errors
        return {
            "status": "error",
            "timestamp": datetime.now().isoformat(),
            "data": [],
            "count": 0,
            "message": f"Error retrieving financial data: {str(e)}"
        }

@tool
def get_current_graphs() -> dict:
    """
    Get all currently displayed graphs.
    
    Returns:
        dict: Response containing list of current graphs
    """
    return {
        "status": "success",
        "timestamp": datetime.now().isoformat(),
        "graphs": [],
        "count": 0,
        "message": "Retrieved current graph portfolio"
    }

@tool
def analyze_and_update_graphs(current_graphs: list) -> dict:
    """
    Analyze current graphs and update them if needed for better trend visualization.
    
    Args:
        current_graphs (list): List of current graph objects
    
    Returns:
        dict: Analysis results and any updates made
    """
    return {
        "status": "success",
        "timestamp": datetime.now().isoformat(),
        "updates_made": 0,
        "updated_graphs": [],
        "analysis": "Analyzed existing graphs for optimization opportunities",
        "recommendations": []
    }

# 1. 
# @tool  
# def find_interesting_relations(financial_data: list) -> dict:
#     """
#     Analyze financial data to find interesting relations between columns using advanced financial analysis techniques.
    
#     Args:
#         financial_data (list): List of financial data records
    
#     Returns:
#         dict: Interesting relations found with financial significance
#     """
    
#     # Turn data into string 
#     data_to_str = str(financial_data)

#     # Ask the model to analyze it 
#     prompt = f"""
#     You are a financial data analyst. Analyze the following financial dataset and
#     extract interesting relations (fraud, profitability, risk, correlations, trends).
        
#     Data sample:
#     {data_str}

#     Respond in JSON with this structure:
#     {{
#       "relations_found": <int>,
#       "relations": [
#         {{
#           "type": "<analysis_type>",
#           "columns": ["col1", "col2"],
#           "strength": "<low|medium|high|numeric>",
#           "insight": "<short summary>"
#         }}
#        ]
#     }}
#     """
    
#     # Run the model 
#     result = model(prompt)

#     # Try parsing 
#     if isinstance(result, str):
#         import json
#         result_json = json.loads(result); 
#     else:
#         result_json = result 
    
#     return {
#         "status": "success",
#         "timestamp": datetime.now().isoformat(),
#         "relations_found": 0,
#         "relations": [],
#         "analysis_types_performed": [
#             "fraud_detection_patterns",
#             "risk_concentration_analysis", 
#             "profitability_trends",
#             "customer_segmentation",
#             "correlation_analysis"
#         ]
#     }

#2. 
# @tool
# def determine_graph_config(relation: dict) -> dict:
#     """
#     Determine the optimal graph type and SQL query for a given financial relation.
    
#     Args:
#         relation (dict): Relation object from find_interesting_relations
    
#     Returns:
#         dict: Optimized graph configuration
#     """
#     return {
#         "status": "success",
#         "graph_type": "bar",
#         "title": "Financial Insight Visualization",
#         "sql_query": "SELECT category, value FROM financial_data GROUP BY category",
#         "description": "Optimized visualization configuration",
#         "rationale": "Graph type selected based on data characteristics and visualization best practices"
#     }

# @tool
# def find_least_useful_graph(current_graphs: list) -> dict:
#     """
#     Analyze current graphs to identify the least useful one for removal based on relevance and value.
    
#     Args:
#         current_graphs (list): List of current graph objects
    
#     Returns:
#         dict: Analysis of least useful graph with detailed reasoning
#     """
#     return {
#         "status": "success",
#         "timestamp": datetime.now().isoformat(),
#         "least_useful_id": None,
#         "reason": "No graphs identified for removal",
#         "usefulness_scores": {},
#         "analysis_criteria": [
#             "data_freshness",
#             "information_value", 
#             "redundancy_check",
#             "statistical_significance"
#         ]
#     }

@tool
def remove_graph(graph_id: int) -> dict:
    """
    Remove a graph by its ID from the dashboard.
    
    Args:
        graph_id (int): ID of the graph to remove
    
    Returns:
        dict: Removal result with confirmation
    """
    return {
        "status": "success",
        "timestamp": datetime.now().isoformat(),
        "removed_id": graph_id,
        "message": f"Successfully removed graph {graph_id} from dashboard"
    }

@tool
def add_new_graph(graph_config: dict) -> dict:
    """
    Add a new graph to the financial dashboard.
    
    Args:
        graph_config (dict): Graph configuration with type, title, sql_query
    
    Returns:
        dict: Addition result with new graph details
    """
    new_id = int(time.time() * 1000) % 100000  # Simple ID generation
    return {
        "status": "success",
        "timestamp": datetime.now().isoformat(), 
        "new_graph_id": new_id,
        "graph": {
            "id": new_id,
            **graph_config
        },
        "message": f"Successfully added new graph: {graph_config.get('title', 'Untitled')}"
    }

@tool
def update_graph(graph_id: int, graph_type: str, sql_query: str, title: str = None) -> dict:
    """
    Update an existing graph's configuration for better visualization.
    
    Args:
        graph_id (int): ID of graph to update
        graph_type (str): New graph type (bar, line, scatter, pie)
        sql_query (str): New SQL query for the graph
        title (str): Optional new title for the graph
    
    Returns:
        dict: Update result with changes made
    """
    changes = {
        "type": graph_type,
        "sql_query": sql_query
    }
    if title:
        changes["title"] = title
        
    return {
        "status": "success",
        "timestamp": datetime.now().isoformat(),
        "updated_graph_id": graph_id,
        "changes": changes,
        "message": f"Successfully updated graph {graph_id}"
    }

# Model configuration
model = LiteLLMModel(
    client_args={
        "api_key": "<KEY>",
    },
    # **model_config
    model_id="gemini/gemini-2.5-flash",
    params={
        "max_tokens": 1000,
        "temperature": 0.7,
    }
)

# Agent configuration
agent = Agent(model=model, tools=[
    get_recent_financial_data,
    get_current_graphs, 
    analyze_and_update_graphs,
    find_interesting_relations,
    determine_graph_config,
    find_least_useful_graph,
    remove_graph,
    add_new_graph,
    update_graph,
    calculator
])

def get_enhanced_financial_prompt(max_graphs: int) -> str:
    """
    Returns the comprehensive financial analysis prompt.
    
    Args:
        max_graphs (int): Maximum number of graphs to maintain
        
    Returns:
        str: Detailed financial analysis prompt
    """
    return f"""
You are a sophisticated Financial Data Analysis Agent responsible for maintaining an optimal dashboard of financial insights. Execute the complete graph management workflow with deep analytical rigor:

## 1. CURRENT GRAPH ANALYSIS & OPTIMIZATION

**Step 1a: Get Current State**
- Use `get_current_graphs()` to retrieve all existing graphs
- Catalog each graph's: id, type, title, sql_query, and current relevance

**Step 1b: Analyze & Update Existing Graphs** 
- Use `analyze_and_update_graphs(current_graphs)` to evaluate each graph for:
  - **Data Freshness**: Does the query capture the most relevant time periods?
  - **Graph Type Optimization**: Is the current chart type optimal for the data pattern?
  - **Query Efficiency**: Can the SQL be optimized for better insights?
  - **Visual Clarity**: Does the title accurately represent the insight?
- Update graphs using `update_graph(graph_id, new_type, new_sql, new_title)` if improvements are identified

## 2. COMPREHENSIVE FINANCIAL DATA ANALYSIS

**Step 2a: Data Acquisition**
- Use `get_recent_financial_data(limit=100)` to fetch the latest financial records
- Ensure data coverage includes recent trends and sufficient historical context

**Step 2b: Advanced Financial Relationship Discovery**
- Use `find_interesting_relations(financial_data)` to perform sophisticated analysis including:

### FRAUD & RISK ANALYSIS
- **Fraud Detection Patterns**: Transaction amount anomalies, frequency spikes, timing irregularities
- **Risk Concentration**: Geographic, demographic, or temporal risk clustering
- **Anomaly Detection**: Unusual payment methods, transaction sizes, customer behaviors

### PERFORMANCE METRICS  
- **Profitability Analysis**: Revenue trends, margin analysis, cost-efficiency ratios
- **Liquidity Assessment**: Cash flow patterns, working capital trends
- **Operational Efficiency**: Processing times, approval rates, conversion metrics

### CUSTOMER & MARKET INSIGHTS
- **Customer Segmentation**: Lifetime value analysis, acquisition cost trends, retention patterns
- **Geographic Performance**: Regional revenue distribution, market penetration analysis
- **Seasonal Intelligence**: Cyclical patterns, holiday impacts, quarterly variations

### CORRELATION ANALYSIS
- **Multi-variable Relationships**: How financial metrics interconnect and influence each other
- **Leading Indicators**: Early warning signals that predict future performance
- **Risk Factor Combinations**: What metric combinations increase fraud or default probability

You are not allowed to use more data than 100 rows

## 3. INTELLIGENT GRAPH CREATION

**Step 3a: Relationship Prioritization**
For each discovered relation, evaluate:
- **Business Impact**: How significant for decision-making?
- **Trend Strength**: How clear and consistent is the pattern?
- **Actionability**: Can stakeholders act on this insight?
- **Novelty**: Does this reveal new information?

**Step 3b: Optimal Graph Configuration**
- Use `determine_graph_config(relation)` for high-priority relationships:
  - **Graph Type Selection**:
    - `bar`: Categorical comparisons (fraud rates by region, revenue by segment)
    - `line`: Time series trends (revenue over time, customer growth)
    - `scatter`: Correlation analysis (risk vs return, cost vs volume)
    - `pie`: Composition analysis (transaction types, market share)
  - **SQL Query Crafting**: Create queries that:
    - Include relevant time filters (last 30/90/365 days)
    - Apply appropriate aggregations (SUM, AVG, COUNT, percentiles)
    - Include meaningful groupings and proper sorting
    - Filter noise and focus on statistically significant data
  - **Title Generation**: Create descriptive, actionable titles like:
    - "Q4 2024 Fraud Rate Surge: Geographic Risk Analysis"
    - "Customer Acquisition Cost vs Lifetime Value by Market Segment"
    - "Processing Time Impact on Transaction Success Rates"
    - "Monthly Revenue Waterfall: Q3 to Q4 2024 Bridge Analysis"
    - "Customer Profitability Matrix: Acquisition Cost vs Lifetime Value"

## 4. STRATEGIC GRAPH PORTFOLIO MANAGEMENT

**Step 4a: Portfolio Assessment**  
- Evaluate current graph count against maximum limit ({max_graphs})
- If at capacity, use `find_least_useful_graph(current_graphs)` based on:
  - **Data Staleness**: Graphs showing outdated or irrelevant trends
  - **Low Information Value**: Visualizations that don't drive decisions
  - **Redundancy**: Similar insights already captured elsewhere
  - **Statistical Insignificance**: Patterns that have become noise

**Step 4b: Strategic Removal & Addition**
- If removal needed: Use `remove_graph(graph_id)` for the least valuable visualization
- Use `add_new_graph(graph_config)` to introduce the most impactful new insight
- Show me the add_new_graph input
- Ensure final portfolio provides:
  - Balanced coverage across fraud, performance, customer, and market domains
  - Mix of time horizons (real-time alerts, short-term trends, long-term patterns)  
  - Actionable intelligence for different stakeholder groups

## 5. COMPREHENSIVE REPORTING

**Step 5a: Executive Summary**
Document:
- **Actions Taken**: Graphs updated, removed, and added with counts
- **Key Insights Discovered**: Most significant financial patterns identified
- **Data Quality Assessment**: Any anomalies, gaps, or data issues observed  
- **Trend Analysis**: Emerging patterns requiring continued monitoring
- **Business Recommendations**: Suggested follow-up analysis or actions

**Step 5b: Technical Details**
- List specific SQL queries modified or created
- Document graph type changes with rationale
- Report on data volume and analysis time period
- Note any performance issues or tool limitations

## SUCCESS CRITERIA
- Maintain exactly {max_graphs} high-value, unique visualizations
- Each graph provides actionable financial intelligence
- Portfolio covers key domains: fraud detection, performance monitoring, customer insights, market analysis
- All graphs use optimal visualization types for their data patterns
- SQL queries are efficient and capture meaningful time periods
- Insights are current, relevant, and statistically significant
- Analysis drives business decisions and risk management

Execute this workflow systematically, ensuring each step builds comprehensive financial intelligence for strategic decision-making.
"""

def run_graph_management_agent(interval_seconds=20, max_iterations=None, max_graphs=6):
    """
    Runs the enhanced financial graph management agent continuously.
    
    Args:
        interval_seconds (int): How often to run the agent (default: 20 seconds)
        max_iterations (int): Maximum number of iterations (None for infinite)
        max_graphs (int): Maximum number of graphs to maintain (default: 6)
    """
    print(f"🚀 Starting Enhanced Financial Data Analysis Agent...")
    print(f"📊 Update interval: {interval_seconds} seconds")
    print(f"📈 Max graphs: {max_graphs}")
    print(f"🔄 Max iterations: {'Unlimited' if max_iterations is None else max_iterations}")
    print(f"⏰ Start time: {datetime.now()}")
    print("=" * 80)
    
    iteration = 0
    
    try:
        while max_iterations is None or iteration < max_iterations:
            iteration += 1
            
            print(f"\n{'='*15} 📊 FINANCIAL ANALYSIS CYCLE {iteration} {'='*15}")
            print(f"🕐 Starting comprehensive analysis at {datetime.now()}")
            
            # Use the enhanced prompt
            message = get_enhanced_financial_prompt(max_graphs)
            
            try:
                result = agent(message)
                print(f"✅ [CYCLE {iteration}] Financial analysis completed successfully")
                
            except Exception as e:
                print(f"❌ [CYCLE {iteration}] Agent error: {e}")
            
            if max_iterations is None or iteration < max_iterations:
                print(f"⏳ [CYCLE {iteration}] Waiting {interval_seconds} seconds until next analysis...")
                print("-" * 80)
                time.sleep(interval_seconds)
    
    except KeyboardInterrupt:
        print(f"\n\n🛑 Received interrupt signal. Stopping after {iteration} iterations.")
        print(f"🏁 End time: {datetime.now()}")
    except Exception as e:
        print(f"\n\n💥 Unexpected error in analysis loop: {e}")
        print(f"🏁 Stopped after {iteration} iterations at {datetime.now()}")

async def run_graph_management_agent_async(interval_seconds=20, max_iterations=1, max_graphs=6):
    """
    Async version of the enhanced financial graph management agent.
    
    Args:
        interval_seconds (int): How often to run the agent
        max_iterations (int): Maximum number of iterations  
        max_graphs (int): Maximum number of graphs to maintain
    """
    print(f"🚀 Starting Async Enhanced Financial Analysis Agent...")
    print(f"📊 Update interval: {interval_seconds} seconds")
    print(f"📈 Max graphs: {max_graphs}")
    print("=" * 80)
    
    iteration = 0
    
    try:
        while max_iterations is None or iteration < max_iterations:
            iteration += 1
            
            print(f"\n🔄 [ASYNC CYCLE {iteration}] Starting comprehensive financial analysis...")
            
            # Use the enhanced prompt
            message = get_enhanced_financial_prompt(max_graphs)
            
            try:
                result = agent(message)
                print(f"✅ [ASYNC CYCLE {iteration}] Financial analysis completed")
                
            except Exception as e:
                print(f"❌ [ASYNC CYCLE {iteration}] Agent error: {e}")
            
            if max_iterations is None or iteration < max_iterations:
                agent.reset()
                await asyncio.sleep(interval_seconds)
    
    except Exception as e:
        print(f"\n💥 Async loop error: {e}")

if __name__ == "__main__":
    print("🎯 Running Enhanced Financial Analysis Agent for 10 iterations (200 seconds total)...")
    run_graph_management_agent(interval_seconds=20, max_iterations=10, max_graphs=6)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 10
#       8 from strands_tools import calculator
#       9 from strands.models.anthropic import AnthropicModel
# ---> 10 from strands.models.google import GoogleGeminiModel
#      11 import anthropic
#      13 import httpx
#
# ModuleNotFoundError: No module named 'strands.models.google'
